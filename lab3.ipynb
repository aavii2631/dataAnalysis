# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
missing_values= df.isnull().sum()

# %%
missing_values
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Salary        0
# dtype: int64

# %%
df.head()
df.tail()
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097

# %%
high_salary = df[df['Salary']>80000]

# %%
print(high_salary)
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 6             7    Employee_7          IT   43   92003
# ..          ...           ...         ...  ...     ...
# 192         193  Employee_193  Operations   52  107575
# 194         195  Employee_195          HR   48  100031
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
#
# [87 rows x 5 columns]

# %%
display(high_salary.head())
# Out:
#    EmployeeID        Name Department  Age  Salary
# 0           1  Employee_1  Marketing   23   91087
# 1           2  Employee_2      Sales   53   98840
# 2           3  Employee_3         IT   44   84384
# 3           4  Employee_4      Sales   43   81005
# 6           7  Employee_7         IT   43   92003

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#      Salary          Name  EmployeeID  Department  Age
# 0     91087    Employee_1           1   Marketing   23
# 1     98840    Employee_2           2       Sales   53
# 2     84384    Employee_3           3          IT   44
# 3     81005    Employee_4           4       Sales   43
# 4     76576    Employee_5           5       Sales   46
# ..      ...           ...         ...         ...  ...
# 195  106429  Employee_196         196          IT   31
# 196  117922  Employee_197         197     Finance   47
# 197   85766  Employee_198         198   Marketing   40
# 198   43403  Employee_199         199          IT   24
# 199   62097  Employee_200         200  Operations   34
#
# [200 rows x 5 columns]

# %%
type(df['Salary'])
# Out:
# pandas.core.series.Series

# %%
df['Salary']
# Out:
# 0       91087
# 1       98840
# 2       84384
# 3       81005
# 4       76576
#         ...
# 195    106429
# 196    117922
# 197     85766
# 198     43403
# 199     62097
# Name: Salary, Length: 200, dtype: int64

# %%
df['Age']
# Out:
# 0      23
# 1      53
# 2      44
# 3      43
# 4      46
#        ..
# 195    31
# 196    47
# 197    40
# 198    24
# 199    34
# Name: Age, Length: 200, dtype: int64

# %%
laddo = df.copy()

# %%
laddo
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
laddo.sort_index(axis=0,ascending=False)
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 199         200  Employee_200  Operations   34   62097
# 198         199  Employee_199          IT   24   43403
# 197         198  Employee_198   Marketing   40   85766
# 196         197  Employee_197     Finance   47  117922
# 195         196  Employee_196          IT   31  106429
# ..          ...           ...         ...  ...     ...
# 4             5    Employee_5       Sales   46   76576
# 3             4    Employee_4       Sales   43   81005
# 2             3    Employee_3          IT   44   84384
# 1             2    Employee_2       Sales   53   98840
# 0             1    Employee_1   Marketing   23   91087
#
# [200 rows x 5 columns]

# %%
laddo.loc[(laddo['Age']>20)]
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
high = df[df['Age']>20 & df['Salary']>90000]
high
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18824\3282010283.py in ?()
# ----> 1 high = df[df['Age']>20 & df['Salary']>90000]
#       2 high
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df = laddo.copy()

# %%
df
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
high = df[df['Age']>20]

# %%
high
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
df.loc[(df['Age']==max) & (df['Salary']==max)]

df
# Out:
#      EmployeeID          Name  Department  Age  Salary
# 0             1    Employee_1   Marketing   23   91087
# 1             2    Employee_2       Sales   53   98840
# 2             3    Employee_3          IT   44   84384
# 3             4    Employee_4       Sales   43   81005
# 4             5    Employee_5       Sales   46   76576
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  106429
# 196         197  Employee_197     Finance   47  117922
# 197         198  Employee_198   Marketing   40   85766
# 198         199  Employee_199          IT   24   43403
# 199         200  Employee_200  Operations   34   62097
#
# [200 rows x 5 columns]

# %%
df['Age'].max()
# Out:
# np.int64(59)

# %%
df['Salary'].max()
# Out:
# np.int64(119912)

# %%
df.drop(['high_salary' , ' age'] , axis= 1 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.drop(['high_salary' , ' age'] , axis= 1 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
# ...

# %%
df = df.rename(columns={'Age':'UMr'})

# %%
df
# Out:
#      EmployeeID          Name  Department  UMr  Salary
# 0             1    Employee_1   Marketing   23  800000
# 1             2    Employee_2       Sales   53  800000
# 2             3    Employee_3          IT   44  800000
# 3             4    Employee_4       Sales   43  800000
# 4             5    Employee_5       Sales   46  800000
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  800000
# 196         197  Employee_197     Finance   47  800000
# 197         198  Employee_198   Marketing   40  800000
# 198         199  Employee_199          IT   24  800000
# 199         200  Employee_200  Operations   34  800000
#
# [200 rows x 5 columns]

# %%
df.loc[:,['Salary']] = 800000

# %%
df
# Out:
#      EmployeeID          Name  Department  UMr  Salary
# 0             1    Employee_1   Marketing   23  800000
# 1             2    Employee_2       Sales   53  800000
# 2             3    Employee_3          IT   44  800000
# 3             4    Employee_4       Sales   43  800000
# 4             5    Employee_5       Sales   46  800000
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31  800000
# 196         197  Employee_197     Finance   47  800000
# 197         198  Employee_198   Marketing   40  800000
# 198         199  Employee_199          IT   24  800000
# 199         200  Employee_200  Operations   34  800000
#
# [200 rows x 5 columns]

# %%
df.loc[:,['Salary']] = 00000000

# %%
df
# Out:
#      EmployeeID          Name  Department  UMr  Salary
# 0             1    Employee_1   Marketing   23       0
# 1             2    Employee_2       Sales   53       0
# 2             3    Employee_3          IT   44       0
# 3             4    Employee_4       Sales   43       0
# 4             5    Employee_5       Sales   46       0
# ..          ...           ...         ...  ...     ...
# 195         196  Employee_196          IT   31       0
# 196         197  Employee_197     Finance   47       0
# 197         198  Employee_198   Marketing   40       0
# 198         199  Employee_199          IT   24       0
# 199         200  Employee_200  Operations   34       0
#
# [200 rows x 5 columns]

# %%
laddo = pd.read_csv('Heart_disease_statlog.csv')

# %%
laddo
# Out:
#       age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    70.0     1.0   3     130.0   322  0.0        2    109.0      0      2.4
# 1    67.0     0.0   2     115.0   564  0.0        2    160.0      0      1.6
# 2    57.0     1.0   1     124.0   261  0.0        0    141.0      0      0.3
# 3    64.0     1.0   3     128.0   263  0.0        0    105.0      1      NaN
# 4    74.0     0.0   1       NaN   269  0.0        2    121.0      1      0.2
# ..    ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 265  52.0     1.0   2     172.0   199  1.0        0    162.0      0      0.5
# 266  44.0     1.0   1     120.0   263  0.0        0    173.0      0      0.0
# 267  56.0     0.0   1     140.0   294  0.0        2    153.0      0      1.3
# 268  57.0     1.0   3     140.0   192  0.0        0    148.0      0      0.4
# 269  67.0     1.0   3     160.0   286  0.0        2    108.0      1      1.5
#
#      slope  ca  thal  target
# ...

# %%
laddo.isnull()
# Out:
#        age  Gender     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False   False  False     False  False  False    False    False  False
# 1    False   False  False     False  False  False    False    False  False
# 2    False   False  False     False  False  False    False    False  False
# 3    False   False  False     False  False  False    False    False  False
# 4    False   False  False      True  False  False    False    False  False
# ..     ...     ...    ...       ...    ...    ...      ...      ...    ...
# 265  False   False  False     False  False  False    False    False  False
# 266  False   False  False     False  False  False    False    False  False
# 267  False   False  False     False  False  False    False    False  False
# 268  False   False  False     False  False  False    False    False  False
# 269  False   False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
laddo.head(5)
# Out:
#     age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  70.0     1.0   3     130.0   322  0.0        2    109.0      0      2.4
# 1  67.0     0.0   2     115.0   564  0.0        2    160.0      0      1.6
# 2  57.0     1.0   1     124.0   261  0.0        0    141.0      0      0.3
# 3  64.0     1.0   3     128.0   263  0.0        0    105.0      1      NaN
# 4  74.0     0.0   1       NaN   269  0.0        2    121.0      1      0.2
#
#    slope  ca  thal  target
# 0      1   3     1       1
# 1      1   0     3       0
# 2      0   0     3       1
# 3      1   1     3       0
# 4      0   1     1       0

# %%
print(laddo.dropna())
# Out:
#       age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    70.0     1.0   3     130.0   322  0.0        2    109.0      0      2.4
# 1    67.0     0.0   2     115.0   564  0.0        2    160.0      0      1.6
# 2    57.0     1.0   1     124.0   261  0.0        0    141.0      0      0.3
# 6    56.0     1.0   2     130.0   256  1.0        2    142.0      1      0.6
# 10   59.0     1.0   3     135.0   234  0.0        0    161.0      0      0.5
# ..    ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 265  52.0     1.0   2     172.0   199  1.0        0    162.0      0      0.5
# 266  44.0     1.0   1     120.0   263  0.0        0    173.0      0      0.0
# 267  56.0     0.0   1     140.0   294  0.0        2    153.0      0      1.3
# 268  57.0     1.0   3     140.0   192  0.0        0    148.0      0      0.4
# 269  67.0     1.0   3     160.0   286  0.0        2    108.0      1      1.5
#
#      slope  ca  thal  target
# ...

# %%
laddo.dropna(how='all')
# Out:
#       age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    70.0     1.0   3     130.0   322  0.0        2    109.0      0      2.4
# 1    67.0     0.0   2     115.0   564  0.0        2    160.0      0      1.6
# 2    57.0     1.0   1     124.0   261  0.0        0    141.0      0      0.3
# 3    64.0     1.0   3     128.0   263  0.0        0    105.0      1      NaN
# 4    74.0     0.0   1       NaN   269  0.0        2    121.0      1      0.2
# ..    ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 265  52.0     1.0   2     172.0   199  1.0        0    162.0      0      0.5
# 266  44.0     1.0   1     120.0   263  0.0        0    173.0      0      0.0
# 267  56.0     0.0   1     140.0   294  0.0        2    153.0      0      1.3
# 268  57.0     1.0   3     140.0   192  0.0        0    148.0      0      0.4
# 269  67.0     1.0   3     160.0   286  0.0        2    108.0      1      1.5
#
#      slope  ca  thal  target
# ...
