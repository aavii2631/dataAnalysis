# %%
df1 = pd.read_csv('ab.csv')
df2 = pd.read_csv('ac.csv')
merged_df = pd.merge(df1, df2)
merged_df.head()
# Out:
#    EmployeeID        Name Department  Age  Salary   Category  Sales
# 0           1  Employee_1         IT   53  107575  Furniture   6167
# 1           2  Employee_2    Finance   53   36655    Grocery  32192
# 2           3  Employee_3      Sales   25  100031    Grocery   6062
# 3           4  Employee_4         IT   51  106429   Clothing  23540
# 4           5  Employee_5         IT   58  117922  Furniture  29244

# %%
pivot_table = pd.pivot_table(merged_df, values='Sales', index='Category', aggfunc='sum')
pivot_table.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
merged_df
# Out:
#      EmployeeID          Name Department  Age  Salary     Category  Sales
# 0             1    Employee_1         IT   53  107575    Furniture   6167
# 1             2    Employee_2    Finance   53   36655      Grocery  32192
# 2             3    Employee_3      Sales   25  100031      Grocery   6062
# 3             4    Employee_4         IT   51  106429     Clothing  23540
# 4             5    Employee_5         IT   58  117922    Furniture  29244
# ..          ...           ...        ...  ...     ...          ...    ...
# 195         196  Employee_196  Marketing   34  116900      Grocery  20254
# 196         197  Employee_197  Marketing   28  119112  Electronics  49238
# 197         198  Employee_198    Finance   57   41130    Furniture   6252
# 198         199  Employee_199      Sales   41  117508     Clothing  44764
# 199         200  Employee_200         IT   22   90566      Grocery  17173
#
# [200 rows x 7 columns]

# %%
import matplotlib.pyplot as plt.3333

# %%
merged_df.plot(kind='bar', x='Category', y='Sales')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Bar Chart')
plt.show()

# %%
merged_df.pivot_table(kind = 'bar' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 merged_df.pivot_table(kind = 'bar' )
#
# TypeError: DataFrame.pivot_table() got an unexpected keyword argument 'kind'

# %%
df = pd.read_csv('employee_sales_P5.csv')

# %%
df
# Out:
#      EmpID           Name  Product  Product_Price  Quantity   Sell_Date  \
# 0    E0001     Employee_1  Printer       50041.16         2  01-01-2023
# 1    E0002     Employee_2   Laptop       73730.18         5  01-01-2023
# 2    E0003     Employee_3   Laptop       62422.03         5  02-01-2023
# 3    E0004     Employee_4  Printer       38260.15         2  03-01-2023
# 4    E0005     Employee_5   Tablet       66407.30         2  03-01-2023
# ..     ...            ...      ...            ...       ...         ...
# 995  E0996   Employee_996   Mobile       11775.49         4  28-12-2024
# 996  E0997   Employee_997  Printer       26728.16         4  28-12-2024
# 997  E0998   Employee_998   Camera        7784.87         2  29-12-2024
# 998  E0999   Employee_999  Printer       38334.99         4  30-12-2024
# 999  E1000  Employee_1000   Tablet       42354.08         2  31-12-2024
#
#     Region  Total_Sale
# 0    South   100082.32
# 1     West   368650.90
# 2     West   312110.15
# ...

# %%
df.isnull().sum()
# Out:
# EmpID            0
# Name             0
# Product          0
# Product_Price    0
# Quantity         0
# Sell_Date        0
# Region           0
# Total_Sale       0
# dtype: int64

# %%
# Out:
#   Cell In[16], line 1
#     parse_dates = ["Sell_Date"],dayfirst=True
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('employee_sales_P5.csv', parse_dates=["Sell_Date"], dayfirst=True)

# %%
df['YearMonth'] = df['Sell_Date'].dt.to_period('M')

# %%
monthly_revenue = df.groupby("YearMonth")["Total_Sale"].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 monthly_revenue = df.groupby("YearMonth")["Total_Sale"].sum().reset_index()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
monthly_revenue
# Out:
#    YearMonth  Total_Sale
# 0    2023-01  5158351.34
# 1    2023-02  4760747.83
# 2    2023-03  4990568.01
# 3    2023-04  5463529.22
# 4    2023-05  5346480.61
# 5    2023-06  5890172.65
# 6    2023-07  5106082.07
# 7    2023-08  4613770.79
# 8    2023-09  5765574.37
# 9    2023-10  5634627.84
# 10   2023-11  6388745.75
# 11   2023-12  4607422.18
# 12   2024-01  5298164.70
# 13   2024-02  4551217.24
# 14   2024-03  5053619.47
# 15   2024-04  5029153.90
# 16   2024-05  5480769.53
# 17   2024-06  4967911.87
# 18   2024-07  5740749.78
# 19   2024-08  5184738.10
# 20   2024-09  5159355.17
# 21   2024-10  5398302.24
# 22   2024-11  5235731.14
# 23   2024-12  4622102.12
